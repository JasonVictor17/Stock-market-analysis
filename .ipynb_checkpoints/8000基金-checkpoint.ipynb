# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
link="http://fund.eastmoney.com/f10/F10DataApi.aspx?type=lsjz&code=000311&page=1&sdate=2018-01-02&edate=2020-01-10&per=20"
headers={
    'user-agent': "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36",
}
r=requests.get(link,headers=headers)

s1 = requests.get(link)
s1.encoding = 'utf-8'
soup1=BeautifulSoup(s1.text,'lxml')
fund_detail=soup1.find_all('tr')

###获取总页数
pattern=re.compile(r'pages:(.*),')
html=r.text
result=re.search(pattern,html).group(1)
pages=int(result)
pages



data_list=[]
for i in range(1, pages+1):
    link='http://fund.eastmoney.com/f10/F10DataApi.aspx?type=lsjz&code=000311&page='+str(i)+'&sdate=2018-01-02&edate=2020-01-10&per=20'
    r=requests.get(link,headers=headers)
    s1 = requests.get(link)
    s1.encoding = 'utf-8'
    soup1=BeautifulSoup(s1.text,'lxml')
    fund_detail=soup1.find_all('tr')
    for each in fund_detail:
       if each.td is None:
        continue
       else:
        date=each.td.text.strip()##only first td
        unit_value=each.find('td',class_='tor bold').text.strip()##first tor bold
        cum_value=each.find('td',class_='tor bold').next_sibling.text.strip()##second td
        percent=each.find('td').next_sibling.next_sibling.next_sibling.text.strip()
        purchase_condition=each.find('td').next_sibling.next_sibling.next_sibling.next_sibling.text.strip()
        sale_condition=each.find('td').next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.text.strip()
        dividend=each.find('td',class_='red unbold').text.strip()
        code= '000311'
        name=  '景顺长城沪深300增强'
        data_list.append([code, name, date,unit_value, cum_value, percent,purchase_condition, sale_condition, dividend])

# %%
len(data_list)
# Out:
# 497

# %%
fund_000311 = pd.DataFrame(data_list)
fund_000311
# Out:
#           0            1           2       3       4       5     6     7 8
# 0    000311  景顺长城沪深300增强  2020-01-10  2.2260  2.5660   0.32%  开放申购  开放赎回
# 1    000311  景顺长城沪深300增强  2020-01-09  2.2190  2.5590   1.46%  开放申购  开放赎回
# 2    000311  景顺长城沪深300增强  2020-01-08  2.1870  2.5270  -1.44%  开放申购  开放赎回
# 3    000311  景顺长城沪深300增强  2020-01-07  2.2190  2.5590   0.91%  开放申购  开放赎回
# 4    000311  景顺长城沪深300增强  2020-01-06  2.1990  2.5390  -0.36%  开放申购  开放赎回
# 5    000311  景顺长城沪深300增强  2020-01-03  2.2070  2.5470  -0.50%  开放申购  开放赎回
# 6    000311  景顺长城沪深300增强  2020-01-02  2.2180  2.5580   1.56%  开放申购  开放赎回
# 7    000311  景顺长城沪深300增强  2019-12-31  2.1840  2.5240   0.46%  开放申购  开放赎回
# 8    000311  景顺长城沪深300增强  2019-12-30  2.1740  2.5140   1.40%  开放申购  开放赎回
# 9    000311  景顺长城沪深300增强  2019-12-27  2.1440  2.4840  -0.14%  开放申购  开放赎回
# 10   000311  景顺长城沪深300增强  2019-12-26  2.1470  2.4870   0.75%  开放申购  开放赎回
# 11   000311  景顺长城沪深300增强  2019-12-25  2.1310  2.4710   0.24%  开放申购  开放赎回
# 477  000311  景顺长城沪深300增强  2018-01-29  2.2610  2.6010  -1.14%  开放申购  开放赎回
# 478  000311  景顺长城沪深300增强  2018-01-26  2.2870  2.6270   0.93%  开放申购  开放赎回
# 479  000311  景顺长城沪深300增强  2018-01-25  2.2660  2.6060   0.00%  开放申购  开放赎回
# 480  000311  景顺长城沪深300增强  2018-01-24  2.2660  2.6060  -0.57%  开放申购  开放赎回
# 481  000311  景顺长城沪深300增强  2018-01-23  2.2790  2.6190   0.97%  开放申购  开放赎回
# 482  000311  景顺长城沪深300增强  2018-01-22  2.2570  2.5970   1.26%  开放申购  开放赎回
# 483  000311  景顺长城沪深300增强  2018-01-19  2.2290  2.5690   0.13%  开放申购  开放赎回
# 484  000311  景顺长城沪深300增强  2018-01-18  2.2260  2.5660   0.45%  开放申购  开放赎回
# 485  000311  景顺长城沪深300增强  2018-01-17  2.2160  2.5560  -0.36%  开放申购  开放赎回
# 486  000311  景顺长城沪深300增强  2018-01-16  2.2240  2.5640   0.59%  开放申购  开放赎回
# 487  000311  景顺长城沪深300增强  2018-01-15  2.2110  2.5510  -0.09%  开放申购  开放赎回
# 488  000311  景顺长城沪深300增强  2018-01-12  2.2130  2.5530   0.55%  开放申购  开放赎回
# 489  000311  景顺长城沪深300增强  2018-01-11  2.2010  2.5410  -0.18%  开放申购  开放赎回
# 490  000311  景顺长城沪深300增强  2018-01-10  2.2050  2.5450   0.14%  开放申购  开放赎回
# 491  000311  景顺长城沪深300增强  2018-01-09  2.2020  2.5420   0.69%  开放申购  开放赎回
# 492  000311  景顺长城沪深300增强  2018-01-08  2.1870  2.5270   0.64%  开放申购  开放赎回
# 493  000311  景顺长城沪深300增强  2018-01-05  2.1730  2.5130   0.28%  开放申购  开放赎回
# 494  000311  景顺长城沪深300增强  2018-01-04  2.1670  2.5070   0.42%  开放申购  开放赎回
# 495  000311  景顺长城沪深300增强  2018-01-03  2.1580  2.4980   0.14%  开放申购  开放赎回
# 496  000311  景顺长城沪深300增强  2018-01-02  2.1550  2.4950   1.94%  开放申购  开放赎回
#
# [497 rows x 9 columns]

# %%
##画出走势图(累计净值)，共1328个交易日，累计净值=单位净值+累计分红
cum_price=fund_000311[['累计净值']]
cum_price=np.array(cum_price)
cum_price=cum_price.tolist()
cum_value=list()
t = np.arange(0.0, 1328.0, 1)
for each in reversed(cum_price):##倒序 从头开始
 cum_price=float(*each)
 cum_value.append(cum_price)
plt.plot(t,cum_value,'r-')
plt.ylabel('value')
plt.xlabel('time') 
plt.title('Fund 000311 HuSheng 300 ')
# Out:
# Text(0.5, 1.0, 'Fund 000311 HuSheng 300 ')

# %%
##涨跌情况
percent=fund_000311[['日增长率']]
percent=np.array(percent)
percent=percent.tolist()
while [''] in percent:
 percent.remove([''])#去除三个空白值
percent_val=[]
t = np.arange(0.0, 1324.0, 1)
i=1
for each in reversed(percent):##倒序 从头开始
   each=float(str(*each).strip('%'))
   percent_val.append(each)
   i=i+1  
plt.plot(t,percent_val,'r-',linewidth=0.5)
plt.ylabel('ratio(%)')
plt.xlabel('time') 
plt.title('Fund 000311 HuSheng 300 ')
##可以看到在第二百到第六百个交易日波动率明显变大，600到1000明显波动率小。
# Out:
# Text(0.5, 1.0, 'Fund 000311 HuSheng 300 ')

# %%
fund_000311.loc[(1327-400):(1327-300)]
##几次极值是2015年7月的暴涨暴跌以及2016年首两个交易日熔断的杰作
# Out:
#                            _id        净值日期 分红送配    单位净值    基金代码         基金名称  \
# 927   5cb2f9a7c15b9b56fb191a86  2015-06-30       2.0910  000311  景顺长城沪深300增强
# 928   5cb2f9a7c15b9b56fb191a87  2015-06-29       1.9760  000311  景顺长城沪深300增强
# 929   5cb2f9a7c15b9b56fb191a88  2015-06-26       2.0260  000311  景顺长城沪深300增强
# 930   5cb2f9a7c15b9b56fb191a89  2015-06-25       2.1840  000311  景顺长城沪深300增强
# 931   5cb2f9a7c15b9b56fb191a8a  2015-06-24       2.2460  000311  景顺长城沪深300增强
# 932   5cb2f9a7c15b9b56fb191a8b  2015-06-23       2.1980  000311  景顺长城沪深300增强
# 933   5cb2f9a7c15b9b56fb191a8c  2015-06-19       2.1260  000311  景顺长城沪深300增强
# 934   5cb2f9a7c15b9b56fb191a8d  2015-06-18       2.2530  000311  景顺长城沪深300增强
# 935   5cb2f9a7c15b9b56fb191a8e  2015-06-17       2.3360  000311  景顺长城沪深300增强
# 936   5cb2f9a7c15b9b56fb191a8f  2015-06-16       2.3030  000311  景顺长城沪深300增强
# 937   5cb2f9a7c15b9b56fb191a90  2015-06-15       2.3760  000311  景顺长城沪深300增强
# 938   5cb2f9a7c15b9b56fb191a91  2015-06-12       2.4270  000311  景顺长城沪深300增强
# 939   5cb2f9a7c15b9b56fb191a92  2015-06-11       2.4110  000311  景顺长城沪深300增强
# 940   5cb2f9a7c15b9b56fb191a93  2015-06-10       2.4130  000311  景顺长城沪深300增强
# 941   5cb2f9a7c15b9b56fb191a94  2015-06-09       2.4150  000311  景顺长城沪深300增强
# 942   5cb2f9a7c15b9b56fb191a95  2015-06-08       2.4530  000311  景顺长城沪深300增强
# 943   5cb2f9a7c15b9b56fb191a96  2015-06-05       2.4030  000311  景顺长城沪深300增强
# 944   5cb2f9a7c15b9b56fb191a97  2015-06-04       2.3760  000311  景顺长城沪深300增强
# 945   5cb2f9a7c15b9b56fb191a98  2015-06-03       2.3620  000311  景顺长城沪深300增强
# 946   5cb2f9a7c15b9b56fb191a99  2015-06-02       2.3680  000311  景顺长城沪深300增强
# 947   5cb2f9a7c15b9b56fb191a9a  2015-06-01       2.3350  000311  景顺长城沪深300增强
# 948   5cb2f9a7c15b9b56fb191a9b  2015-05-29       2.2270  000311  景顺长城沪深300增强
# 949   5cb2f9a7c15b9b56fb191a9c  2015-05-28       2.2210  000311  景顺长城沪深300增强
# 950   5cb2f9a7c15b9b56fb191a9d  2015-05-27       2.3790  000311  景顺长城沪深300增强
# 1008   0.44%  开放申购  1.5900  开放赎回
# 1009  -2.28%  开放申购  1.5830  开放赎回
# 1010   1.00%  开放申购  1.6200  开放赎回
# 1011   0.06%  开放申购  1.6040  开放赎回
# 1012   2.30%  开放申购  1.6030  开放赎回
# 1013  -0.95%  开放申购  1.5670  开放赎回
# 1014   0.89%  开放申购  1.5820  开放赎回
# 1015   0.45%  开放申购  1.5680  开放赎回
# 1016   0.77%  开放申购  1.5610  开放赎回
# 1017   0.32%  开放申购  1.5490  开放赎回
# 1018   0.59%  开放申购  1.5440  开放赎回
# 1019   1.86%  开放申购  1.5350  开放赎回
# 1020   0.87%  开放申购  1.5070  开放赎回
# 1021  -1.32%  开放申购  1.4940  开放赎回
# 1022  -0.85%  开放申购  1.5140  开放赎回
# 1023  -0.97%  开放申购  1.5270  开放赎回
# 1024   2.25%  开放申购  1.5420  开放赎回
# 1025  -1.82%  开放申购  1.5080  开放赎回
# 1026  -1.29%  开放申购  1.5360  开放赎回
# 1027  -1.39%  开放申购  1.5560  开放赎回
#
# [101 rows x 10 columns]

# %%
##基金定投研究
unit_price=fund_000311[['单位净值']]
unit_price=np.array(unit_price)
unit_price=unit_price.tolist()

# %%
##查出分红情况
dividend=fund_000311.loc[fund_000311['分红送配'] != '']
dividend
# Out:
#                           _id        净值日期          分红送配    单位净值    基金代码  \
# 406  5cb2f9a7c15b9b56fb19187d  2017-08-15  每份派现金0.1500元  1.9260  000311
# 413  5cb2f9a7c15b9b56fb191884  2017-08-04  每份派现金0.1900元  2.0790  000311
#
#             基金名称    日增长率    申购状态    累计净值  赎回状态
# 406  景顺长城沪深300增强   0.34%  限制大额申购  2.2660  开放赎回
# 413  景顺长城沪深300增强  -0.70%  限制大额申购  2.2690  开放赎回

# %%
###假如从15年6月8日高位开始定投至今，对比一次性投入。 金额=100000。
###一次性投入：
pie=100000/2.453##份额
present_value_once=pie*2.472
(present_value_once-100000)/100000##大约收益率0.77%
# Out:
# 0.007745617611088528

# %%
###假如从15年6月8日高位开始定投至今，对比一次性投入。 金额=100000。
###隔五个交易日定投一次：
unit_price_new_1=unit_price[0:406:5]
unit_price_new_2=unit_price[407:413:5]
unit_price_new_3=unit_price[414:942:5]
unit_price_new_1=np.array(unit_price_new_1)
unit_price_new_2=np.array(unit_price_new_2)
unit_price_new_3=np.array(unit_price_new_3)
unit_price_new_1=unit_price_new_1.tolist()
unit_price_new_2=unit_price_new_2.tolist()
unit_price_new_3=unit_price_new_3.tolist()
each_amount=100000/(len(unit_price_new_1)+len(unit_price_new_2)+len(unit_price_new_3))
each_pie_1=[]
for each in (unit_price_new_1):##倒序 从头开始
 each=float(*each)
 pie=each_amount/each
 each_pie_1.append(pie)
each_pie_2=[]
for each in (unit_price_new_2):##倒序 从头开始
 each=float(*each)
 pie=each_amount/each
 each_pie_2.append(pie)
each_pie_3=[]
for each in (unit_price_new_3):##倒序 从头开始
 each=float(*each)
 pie=each_amount/each
 each_pie_3.append(pie)
dividend_add=sum(each_pie_3)*0.19+(sum(each_pie_3)+sum(each_pie_2))*0.15
(dividend_add+(sum(each_pie_3)+sum(each_pie_2)+sum(each_pie_1))*2.132-100000)/100000##大约收益率25%
# Out:
# 0.2487520514881557

# %%
###假如从15年6月8日高位开始定投至今，对比一次性投入。 金额=100000。
###每个交易日定投一次：
unit_price_new_1=unit_price[0:406]
unit_price_new_2=unit_price[407:413]
unit_price_new_3=unit_price[414:937]
unit_price_new_1=np.array(unit_price_new_1)
unit_price_new_2=np.array(unit_price_new_2)
unit_price_new_3=np.array(unit_price_new_3)
unit_price_new_1=unit_price_new_1.tolist()
unit_price_new_2=unit_price_new_2.tolist()
unit_price_new_3=unit_price_new_3.tolist()
each_amount=100000/(len(unit_price_new_1)+len(unit_price_new_2)+len(unit_price_new_3))
each_pie_1=[]
for each in (unit_price_new_1):##倒序 从头开始
 each=float(*each)
 pie=each_amount/each
 each_pie_1.append(pie)
each_pie_2=[]
for each in (unit_price_new_2):##倒序 从头开始
 each=float(*each)
 pie=each_amount/each
 each_pie_2.append(pie)
each_pie_3=[]
for each in (unit_price_new_3):##倒序 从头开始
 each=float(*each)
 pie=each_amount/each
 each_pie_3.append(pie)
dividend_add=sum(each_pie_3)*0.19+(sum(each_pie_3)+sum(each_pie_2))*0.15
(dividend_add+(sum(each_pie_3)+sum(each_pie_2)+sum(each_pie_1))*2.132-100000)/100000##大约收益率25.3% 

##可见每个交易日定投与每周定投并无很大区别。
##为方便计算，忽略了时间价值，目的阐述定投好处。如果考虑时间价值则定投必然优于一次性买入。
# Out:
# 0.2529015983109204

# %%
###假如从16年1月28日低位开始定投至今，对比一次性投入。 金额=100000。
###once：
pie=100000/1.4370##份额##包含两次分红用累计净值便可
present_value_once=pie*2.472
(present_value_once-100000)/100000##大约收益率72%
# Out:
# 0.720250521920668

# %%
###假如从16年1月28日低位开始定投至今，对比一次性投入。 金额=100000。
###每5个交易日定投一次：
unit_price_new_1=unit_price[0:406]
unit_price_new_2=unit_price[407:413]
unit_price_new_3=unit_price[414:783]
unit_price_new_1=np.array(unit_price_new_1)
unit_price_new_2=np.array(unit_price_new_2)
unit_price_new_3=np.array(unit_price_new_3)
unit_price_new_1=unit_price_new_1.tolist()
unit_price_new_2=unit_price_new_2.tolist()
unit_price_new_3=unit_price_new_3.tolist()
each_amount=100000/(len(unit_price_new_1)+len(unit_price_new_2)+len(unit_price_new_3))
each_pie_1=[]
for each in (unit_price_new_1):##倒序 从头开始
 each=float(*each)
 pie=each_amount/each
 each_pie_1.append(pie)
each_pie_2=[]
for each in (unit_price_new_2):##倒序 从头开始
 each=float(*each)
 pie=each_amount/each
 each_pie_2.append(pie)
each_pie_3=[]
for each in (unit_price_new_3):##倒序 从头开始
 each=float(*each)
 pie=each_amount/each
 each_pie_3.append(pie)
dividend_add=sum(each_pie_3)*0.19+(sum(each_pie_3)+sum(each_pie_2))*0.15
(dividend_add+(sum(each_pie_3)+sum(each_pie_2)+sum(each_pie_1))*2.132-100000)/100000##大约收益率22.17% 
##可见定投收益率比较稳定，而一次性虽然可能获取更高收益但是最终收益率的波动性比较大。
# Out:
# 0.22174400565187868

# %%
###模拟
##定投
times= np.arange(414, 1327, 1)
final_percent=[]
for i in times:
 each_pie_1=[]
 each_pie_2=[]
 each_pie_3=[]
 unit_price_new_1=unit_price[0:406]
 unit_price_new_2=unit_price[407:413]
 unit_price_new_3=unit_price[414:i]
 unit_price_new_1=np.array(unit_price_new_1)
 unit_price_new_2=np.array(unit_price_new_2)
 unit_price_new_3=np.array(unit_price_new_3)
 unit_price_new_1=unit_price_new_1.tolist()
 unit_price_new_2=unit_price_new_2.tolist()
 unit_price_new_3=unit_price_new_3.tolist()
 each_amount=100000/(len(unit_price_new_1)+len(unit_price_new_2)+len(unit_price_new_3))
 
 for each in (unit_price_new_1):##倒序 从头开始
  each=float(*each)
  pie=each_amount/each
  each_pie_1.append(pie)
 
 for each in (unit_price_new_2):##倒序 从头开始
  each=float(*each)
  pie=each_amount/each
  each_pie_2.append(pie)
 
 for each in (unit_price_new_3):##倒序 从头开始
  each=float(*each)
  pie=each_amount/each
  each_pie_3.append(pie)
 dividend_add=sum(each_pie_3)*0.19+(sum(each_pie_3)+sum(each_pie_2))*0.15
 final_percent.append((dividend_add+(sum(each_pie_3)+sum(each_pie_2)+sum(each_pie_1))*2.132-100000)/100000)
final_percent_test=pd.DataFrame(final_percent)

# %%
final_percent_test.describe()
# Out:
#                 0
# count  913.000000
# mean     0.247417
# std      0.105737
# min      0.105204
# 25%      0.159612
# 50%      0.243204
# 75%      0.295816
# max      0.497570

# %%
t = np.arange(414, 1327.0, 1)
plt.plot(t,final_percent_test,'r-')
plt.ylabel('ratio(%)')
plt.xlabel('time') 
plt.title('Fund 000311 automatic investment ')
# Out:
# Text(0.5, 1.0, 'Fund 000311 automatic investment ')

# %%
plt.hist(final_percent, bins=50,facecolor="blue", edgecolor="black", alpha=0.7)
# Out:
# (array([ 65.,  38.,  29.,  23.,  30.,  23.,  22.,  23.,  19.,  16.,  15.,
#          19.,  19.,  16.,  14.,  33.,  41.,  19., 142.,  25.,  20.,  12.,
#          10.,   9.,   9.,   9.,   9.,   9.,   9.,   9.,   9.,   7.,   8.,
#           8.,   7.,   8.,   8.,   8.,   9.,   8.,   9.,   8.,   9.,   9.,
#           9.,   9.,  10.,  10.,  12.,  12.]),
#  array([0.10520361, 0.11305093, 0.12089825, 0.12874557, 0.13659289,
#         0.14444022, 0.15228754, 0.16013486, 0.16798218, 0.1758295 ,
#         0.18367682, 0.19152414, 0.19937146, 0.20721879, 0.21506611,
#         0.22291343, 0.23076075, 0.23860807, 0.24645539, 0.25430271,
#         0.26215004, 0.26999736, 0.27784468, 0.285692  , 0.29353932,
#         0.30138664, 0.30923396, 0.31708128, 0.32492861, 0.33277593,
#         0.34062325, 0.34847057, 0.35631789, 0.36416521, 0.37201253,
#         0.37985985, 0.38770718, 0.3955545 , 0.40340182, 0.41124914,
#         0.41909646, 0.42694378, 0.4347911 , 0.44263843, 0.45048575,
#         0.45833307, 0.46618039, 0.47402771, 0.48187503, 0.48972235,
#         0.49756967]),
#  <a list of 50 Patch objects>)

# %%
###模拟
##一次
new_present_value_once=[]
unit_price_new=unit_price[414:1327]
for i in unit_price_new:
 i=float(*i)
 pie=100000/i ##份额
 present_value_once=pie*2.472
 new_present_value_once.append((present_value_once-100000)/100000)
new_present_value_once_test=pd.DataFrame(new_present_value_once)

# %%
new_present_value_once_test.describe()
# Out:
#                 0
# count  913.000000
# mean     0.675401
# std      0.503908
# min      0.007746
# 25%      0.301053
# 50%      0.493656
# 75%      1.253418
# max      1.672432

# %%
plt.plot(t,new_present_value_once_test,'r-')
plt.ylabel('ratio(%)')
plt.xlabel('time') 
plt.title('Fund 000311 normal investment ')
# Out:
# Text(0.5, 1.0, 'Fund 000311 normal investment ')

# %%
plt.hist(new_present_value_once, bins=50,facecolor="red", edgecolor="black", alpha=0.7)
# Out:
# (array([10.,  7., 20., 23., 16., 36., 37., 49., 40., 67., 51., 39., 21.,
#         22., 33., 41., 55., 30., 20., 19.,  5.,  6.,  4.,  1.,  1.,  1.,
#          0.,  1.,  1.,  1.,  1.,  1.,  2.,  5.,  4.,  6.,  5., 20., 12.,
#         23., 17.,  5.,  7., 16., 18., 20., 46., 35.,  9.,  4.]),
#  array([0.00774562, 0.04103935, 0.07433309, 0.10762683, 0.14092056,
#         0.1742143 , 0.20750804, 0.24080177, 0.27409551, 0.30738924,
#         0.34068298, 0.37397672, 0.40727045, 0.44056419, 0.47385793,
#         0.50715166, 0.5404454 , 0.57373913, 0.60703287, 0.64032661,
#         0.67362034, 0.70691408, 0.74020782, 0.77350155, 0.80679529,
#         0.84008903, 0.87338276, 0.9066765 , 0.93997023, 0.97326397,
#         1.00655771, 1.03985144, 1.07314518, 1.10643892, 1.13973265,
#         1.17302639, 1.20632012, 1.23961386, 1.2729076 , 1.30620133,
#         1.33949507, 1.37278881, 1.40608254, 1.43937628, 1.47267001,
#         1.50596375, 1.53925749, 1.57255122, 1.60584496, 1.6391387 ,
#         1.67243243]),
#  <a list of 50 Patch objects>)

# %%
###短线--v型走势
###模拟
##定投
each_pie_1=[]

unit_price_new_1=unit_price[0:310:5]

unit_price_new_1=np.array(unit_price_new_1)

unit_price_new_1=unit_price_new_1.tolist()

each_amount=100000/(len(unit_price_new_1))
 
for each in (unit_price_new_1):##倒序 从头开始
  each=float(*each)
  pie=each_amount/each
  each_pie_1.append(pie)
(sum(each_pie_1)*2.132-100000)/100000
# Out:
# 0.1259953947969366

# %%
unit_price[310]
# Out:
# ['2.1580']

# %%
###once：
pie=100000/2.1580##份额##包含两次分红用累计净值便可
present_value_once=pie*2.132
(present_value_once-100000)/100000##大约收益率-0.012%
# Out:
# -0.01204819277108414
